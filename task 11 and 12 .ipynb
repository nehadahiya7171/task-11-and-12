# %%
## task 11 and 12

# %%
def add(x,y):
    num_1=x+y
    print(num_1)

# %%
add(10,20)
# Out:
# 30

# %%
def add(x,y):
    num_2=x+y
    print(num_2)

# %%
add(20,50)
# Out:
# 70

# %%
## addition

# %%
def add(x,y):
    z=x+y
    print(z)

# %%
add(20,10)
# Out:
# 30

# %%
# subtraction

# %%
def sub(x,y):
    z=x-y
    print(z)

# %%
sub(30,20)
# Out:
# 10

# %%
# multiplication

# %%
def product(x,y):
    z=x*y
    print(z)

# %%
my_num=product(10,2)
# Out:
# 20

# %%
# division

# %%
def division(x,y):
    z=x%y
    print(z)

# %%
my_num=division(15,3)
# Out:
# 0

# %%
## for example i want to write no 15

# %%
def add_10(x):
    return x+10

# %%
add_10(5)
# Out:
# 15

# %%
## if user want the no  20

# %%
add_10(10)
# Out:
# 20

# %%
##task 12

# %%
## lambda with filter

# %%
l1=[10,20,30,45,68,75,20]
new_list=list(filter(lambda x:(x%2==0),l1))

# %%
new_list
# Out:
# [10, 20, 30, 68, 20]

# %%
## labda with reduce

# %%
from functools import reduce

# %%
l1=[1,2,3,4,5,6]
sum=reduce(lambda x,y :x+y,l1)

# %%
sum
# Out:
# 21
